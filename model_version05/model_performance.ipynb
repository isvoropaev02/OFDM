# %%
# 18.05.2024
# обновлена схема, построены графики для пилотного сигнала

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft
# %matplotlib widget

# %% [markdown]
# ### При использовании QAM4

# %%
mimo11_4 = pd.read_csv('mimo_1x1_QAM4.txt', sep=',',header=0, skipinitialspace=True)
mimo12_4 = pd.read_csv('mimo_1x2_QAM4.txt', sep=',',header=0, skipinitialspace=True)
mimo22_4 = pd.read_csv('mimo_2x2_QAM4.txt', sep=',',header=0, skipinitialspace=True)
mimo14_4 = pd.read_csv('mimo_1x4_QAM4.txt', sep=',',header=0, skipinitialspace=True)
mimo22_64 = pd.read_csv('mimo_2x2_QAM64.txt', sep=',',header=0, skipinitialspace=True)

# %%
mimo11_4.head()
# Out:
#    SNR_dB    BER_ZF  BER_MMSE    EVM_ZF  EVM_MMSE
# 0     0.0  0.232744  0.232744  2.487125  0.832279
# 1     3.0  0.145391  0.145391  2.163263  0.714275
# 2     6.0  0.076936  0.076936  1.242815  0.588326
# 3     9.0  0.037009  0.037009  0.872822  0.470122
# 4    12.0  0.017836  0.017836  0.663661  0.366510

# %%
fig1 = plt.figure(figsize=(8,5))
ax_1 = fig1.add_subplot(111)
ax_1.plot(mimo22_4['SNR_dB'], 20*np.log10(mimo22_4['EVM_ZF']), label='Zero-Forcing (QPSK)')
ax_1.plot(mimo22_4['SNR_dB'], 20*np.log10(mimo22_4['EVM_MMSE']), label='MMSE (QPSK)')
ax_1.plot(mimo22_64['SNR_dB'], 20*np.log10(mimo22_64['EVM_ZF']), label='Zero-Forcing (QAM64)')
ax_1.plot(mimo22_64['SNR_dB'], 20*np.log10(mimo22_64['EVM_MMSE']), label='MMSE (QAM64)')
ax_1.grid()
ax_1.set_xlabel('SNR [dB]')
ax_1.set_ylabel('EVM [dB]')
ax_1.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig2 = plt.figure(figsize=(8,5))
ax_1 = fig2.add_subplot(111)
ax_1.plot(mimo22_4['SNR_dB'], mimo22_4['BER_ZF'], label='Zero-Forcing (QPSK)')
ax_1.plot(mimo22_4['SNR_dB'], mimo22_4['BER_MMSE'], label='MMSE (QPSK)')
ax_1.plot(mimo22_64['SNR_dB'], mimo22_64['BER_ZF'], label='Zero-Forcing (QAM64)')
ax_1.plot(mimo22_64['SNR_dB'], mimo22_64['BER_MMSE'], label='MMSE (QAM64)')
ax_1.set_yscale('log')
ax_1.grid()
ax_1.set_xlabel('SNR [dB]')
ax_1.set_ylabel('Uncoded BER')
ax_1.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig3 = plt.figure(figsize=(8,5))
ax_1 = fig3.add_subplot(111)
ax_1.plot(mimo11_4['SNR_dB'], mimo11_4['BER_MMSE'], label='SISO 1x1')
ax_1.plot(mimo12_4['SNR_dB'], mimo12_4['BER_MMSE'], label='SIMO 1x2')
ax_1.plot(mimo14_4['SNR_dB'], mimo14_4['BER_MMSE'], label='SIMO 1x4')
ax_1.set_yscale('log')
ax_1.grid()
ax_1.set_xlabel('SNR [dB]')
ax_1.set_ylabel('Uncoded BER')
ax_1.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig4 = plt.figure(figsize=(8,5))
ax_1 = fig4.add_subplot(111)
ax_1.plot(mimo11_4['SNR_dB'], 20*np.log10(mimo11_4['EVM_MMSE']), label='SISO 1x1')
ax_1.plot(mimo12_4['SNR_dB'], 20*np.log10(mimo12_4['EVM_MMSE']), label='SIMO 1x2')
ax_1.plot(mimo14_4['SNR_dB'], 20*np.log10(mimo14_4['EVM_MMSE']), label='SIMO 1x4')
ax_1.grid()
ax_1.set_xlabel('SNR [dB]')
ax_1.set_ylabel('EVM [dB]')
ax_1.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
